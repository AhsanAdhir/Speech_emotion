# %% [markdown]
# <a href="https://colab.research.google.com/github/AhsanAdhir/Speech_emotion/blob/main/Emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/speech_emotion.zip'  # Change this to match your file
extract_path = '/content/speech_emotion'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import glob

# Get all wav files from subdirectories (24 actors)
audio_files = glob.glob(os.path.join(extract_path, '**', '*.wav'), recursive=True)

print(f"Total audio files found: {len(audio_files)}")
print("Example file path:", audio_files[0])
# Out:
# Total audio files found: 1440
# Example file path: /content/speech_emotion/speech_emotion/Actor_15/03-01-03-02-02-02-15.wav
